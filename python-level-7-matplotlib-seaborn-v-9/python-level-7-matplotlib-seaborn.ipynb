# %% [markdown]
# # python-level-7-matplotlib-seaborn
#
# Use the "Run" button to execute the code.

# %%
# !pip install jovian --upgrade --quiet

# %%
import jovian

# %%
# Execute this to save new versions of the notebook
jovian.commit(project="python-level-7-matplotlib-seaborn")
# Out:
# [jovian] Updating notebook "asad-cuet/python-level-7-matplotlib-seaborn" on https://jovian.ai
# [jovian] Committed successfully! https://jovian.ai/asad-cuet/python-level-7-matplotlib-seaborn
# 'https://jovian.ai/asad-cuet/python-level-7-matplotlib-seaborn'

# %% [markdown]
# # Matplotlib & Seaborn

# %%
import matplotlib.pyplot as plt
import seaborn as sns
#matplotlib & seaborn work together

# %%
years = range(2000, 2012)
apples = [0.895, 0.91, 0.919, 0.926, 0.929, 0.931, 0.934, 0.936, 0.937, 0.9375, 0.9372, 0.939]
oranges = [0.962, 0.941, 0.930, 0.923, 0.918, 0.908, 0.907, 0.904, 0.901, 0.898, 0.9, 0.896, ]

# %% [markdown]
# ### Line Chart

# %%
plt.plot(apples)

# %%
plt.plot(years,apples)  #(x-axis,y-axis)

# %%
plt.plot(years,apples)
plt.plot(years,oranges)

# %%
plt.figure(figsize=(12, 6))   #changing figure size
plt.plot(years,apples,marker='o',c='red')
plt.plot(years,oranges,marker='x',ls='--')

plt.xlabel('Years')
plt.ylabel('Yields')

plt.title('A title')

plt.legend(['Apples','Orange'])  #indicating the line

# %% [markdown]
# ### Summery

# %% [markdown]
# #### plt.figure(figsize=(12, 6))   #changing figure size
# #### xlabel(),ylabel(),title(),legend([]),
# #### plot(x,y,marker='')
# #### Styling Lines and Markers
# #### The plt.plot function supports many arguments for styling lines and mark#### #### e######## ####  rs:
#
# #### 1.color or c: Set the color of the line (supported colors)
# #### 2.linestyle or ls: Choose between a solid or dashed line
# #### 3.linewidth or lw: Set the width of a line   .value is '2' or 'any number' only
# #### 4.markersize or ms: Set the size of markers
# #### 5.markeredgecolor or mec: Set the edge color for markers
# #### 6.markeredgewidth or mew: Set the edge width for markers
# #### 7.markerfacecolor or mfc: Set the fill color for markers
# #### 8.alpha: Opacity of the plot

# %% [markdown]
# ### Changing default syle by seaborn

# %%
sns.set_style('whitegrid')
plt.plot(years,apples)

# %%
sns.set_style('darkgrid')
plt.plot(years,apples)

# %% [markdown]
# ### Changing default style directly

# %%
import matplotlib
matplotlib.rcParams['font.size'] = 14
matplotlib.rcParams['figure.figsize'] = (9, 5)
matplotlib.rcParams['figure.facecolor'] = '#00000000'

# %%
plt.plot(years,apples)

# %% [markdown]
# ### load Data by Seaborn

# %%
import matplotlib.pyplot as plt
import seaborn as sns
#matplotlib & seaborn work together

# %%
flowers_df = sns.load_dataset("iris")

# %%
flowers_df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# #### Print column

# %%
flowers_df.species
# Out:
# 0         setosa
# 1         setosa
# 2         setosa
# 3         setosa
# 4         setosa
#          ...
# 145    virginica
# 146    virginica
# 147    virginica
# 148    virginica
# 149    virginica
# Name: species, Length: 150, dtype: object

# %% [markdown]
# #### find uniqui() value of a column

# %%
flowers_df.species.unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %% [markdown]
# ### Plot data from datasheet

# %% [markdown]
# #### By plot()

# %%
length=flowers_df.sepal_length
width=flowers_df.sepal_width
plt.plot(length,width)

# %% [markdown]
# #### By scatterplot(x=,y=) from sns  [more informative]

# %%
sns.scatterplot(x=length,y=width);

# %%
sns.scatterplot(x=length,y=width,hue=flowers_df.species, s=100); # s is point size

# %% [markdown]
# #### ploy() scatterplot() together

# %%
plt.figure(figsize=(12, 6))
plt.title('Sepal Dimensions')
plt.xlabel('Sepal Length')
plt.ylabel('Sepal Width')
# Out:
# Text(0, 0.5, 'Sepal Width')

# %%
plt.figure(figsize=(12, 6))
plt.title('Sepal Dimensions')
sns.scatterplot(x=length,y=width,hue=flowers_df.species, s=100)
# Out:
# <AxesSubplot:title={'center':'Sepal Dimensions'}, xlabel='sepal_length', ylabel='sepal_width'>

# %% [markdown]
# ### Plot data from datasheet in 1 line

# %%
plt.title('Sepal Dimensions')
sns.scatterplot(x='sepal_length', 
                y='sepal_width', 
                hue='species',
                s=100,
                data=flowers_df);  #datasheet here

# %% [markdown]
# # Historam from matplotlib

# %% [markdown]
# ### 1 column

# %% [markdown]
# #### Histogram
# #### A histogram represents the distribution of a variable by creating bins (interval) along the range of values and showing vertical #### bars to indicate the number of observations in each bin.
#
# #### For example, let's visualize the distribution of values of sepal width in the flowers dataset. We can use the plt.hist function to #### create a histogram

# %%
plt.title('Distribution os Sepal Width')
plt.hist(width)
# Out:
# (array([ 4.,  7., 22., 24., 37., 31., 10., 11.,  2.,  2.]),
#  array([2.  , 2.24, 2.48, 2.72, 2.96, 3.2 , 3.44, 3.68, 3.92, 4.16, 4.4 ]),
#  <BarContainer object of 10 artists>)

# %%
plt.title('Distribution os Sepal Width')
plt.hist(width,bins=5)   #controlling the bar
# Out:
# (array([11., 46., 68., 21.,  4.]),
#  array([2.  , 2.48, 2.96, 3.44, 3.92, 4.4 ]),
#  <BarContainer object of 5 artists>)

# %%
import numpy as np

# %%
plt.hist(width,bins=np.arange(2,5,0.25))   # arange=[2.   2.25 2.5  2.75 3.   3.25 3.5  3.75 4.   4.25 4.5  4.75]
# Out:
# (array([ 4.,  7., 22., 24., 50., 18., 13.,  8.,  3.,  1.,  0.]),
#  array([2.  , 2.25, 2.5 , 2.75, 3.  , 3.25, 3.5 , 3.75, 4.  , 4.25, 4.5 ,
#         4.75]),
#  <BarContainer object of 11 artists>)

# %% [markdown]
# ### Multiple Histogram

# %%
#querying
setosa_df = flowers_df[flowers_df.species == 'setosa']
versicolor_df = flowers_df[flowers_df.species == 'versicolor']
virginica_df = flowers_df[flowers_df.species == 'virginica']

# %%
setosa_df
# Out:
#     sepal_length  sepal_width  petal_length  petal_width species
# 0            5.1          3.5           1.4          0.2  setosa
# 1            4.9          3.0           1.4          0.2  setosa
# 2            4.7          3.2           1.3          0.2  setosa
# 3            4.6          3.1           1.5          0.2  setosa
# 4            5.0          3.6           1.4          0.2  setosa
# 5            5.4          3.9           1.7          0.4  setosa
# 6            4.6          3.4           1.4          0.3  setosa
# 7            5.0          3.4           1.5          0.2  setosa
# 8            4.4          2.9           1.4          0.2  setosa
# 9            4.9          3.1           1.5          0.1  setosa
# 10           5.4          3.7           1.5          0.2  setosa
# 11           4.8          3.4           1.6          0.2  setosa
# 12           4.8          3.0           1.4          0.1  setosa
# ...

# %%
versicolor_df
# Out:
#     sepal_length  sepal_width  petal_length  petal_width     species
# 50           7.0          3.2           4.7          1.4  versicolor
# 51           6.4          3.2           4.5          1.5  versicolor
# 52           6.9          3.1           4.9          1.5  versicolor
# 53           5.5          2.3           4.0          1.3  versicolor
# 54           6.5          2.8           4.6          1.5  versicolor
# 55           5.7          2.8           4.5          1.3  versicolor
# 56           6.3          3.3           4.7          1.6  versicolor
# 57           4.9          2.4           3.3          1.0  versicolor
# 58           6.6          2.9           4.6          1.3  versicolor
# 59           5.2          2.7           3.9          1.4  versicolor
# 60           5.0          2.0           3.5          1.0  versicolor
# 61           5.9          3.0           4.2          1.5  versicolor
# 62           6.0          2.2           4.0          1.0  versicolor
# ...

# %%
virginica_df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 100           6.3          3.3           6.0          2.5  virginica
# 101           5.8          2.7           5.1          1.9  virginica
# 102           7.1          3.0           5.9          2.1  virginica
# 103           6.3          2.9           5.6          1.8  virginica
# 104           6.5          3.0           5.8          2.2  virginica
# 105           7.6          3.0           6.6          2.1  virginica
# 106           4.9          2.5           4.5          1.7  virginica
# 107           7.3          2.9           6.3          1.8  virginica
# 108           6.7          2.5           5.8          1.8  virginica
# 109           7.2          3.6           6.1          2.5  virginica
# 110           6.5          3.2           5.1          2.0  virginica
# 111           6.4          2.7           5.3          1.9  virginica
# 112           6.8          3.0           5.5          2.1  virginica
# ...

# %%
plt.hist(setosa_df.sepal_width, alpha=0.4, bins=np.arange(2, 5, 0.25));
plt.hist(versicolor_df.sepal_width, alpha=0.4, bins=np.arange(2, 5, 0.25));

# %% [markdown]
# #### 1 line & overlapping

# %%
plt.title('Distribution of Sepal Width')

plt.hist([setosa_df.sepal_width, versicolor_df.sepal_width, virginica_df.sepal_width], 
         bins=np.arange(2, 5, 0.25), 
         stacked=True);

plt.legend(['Setosa', 'Versicolor', 'Virginica']);

# %% [markdown]
# # Bar Chart from matplotlib

# %% [markdown]
# #### bar(x,y)

# %%
years = range(2000, 2006)
apples = [0.35, 0.6, 0.9, 0.8, 0.65, 0.8]
oranges = [0.4, 0.8, 0.9, 0.7, 0.6, 0.8]

# %%
plt.bar(years, oranges); #sns.barplot() from sns

# %% [markdown]
# #### 2 bar together

# %%
plt.bar(years, apples)
plt.bar(years, oranges, bottom=apples);

# %% [markdown]
# ### Plot with average

# %%
tips_df = sns.load_dataset("tips");

# %%
tips_df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# #### Seaborn library provides a barplot function which can automatically compute averages.
#
# #### The lines cutting each bar represent the amount of variation in the values. For instance, it seems like the variation in the total bill #### is relatively high on Fridays and low on Saturday.

# %%
sns.barplot(x='day', y='total_bill', data=tips_df);

# %% [markdown]
# #### We can also specify a hue argument to compare bar plots side-by-side based on a third feature, e.g., sex.

# %%
sns.barplot(x='day', y='total_bill', hue='sex', data=tips_df);

# %% [markdown]
# #### Horizontal bar

# %%
sns.barplot(x='total_bill', y='day', hue='sex', data=tips_df);
